# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
penguins=sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
#CLEANING
##DUPLICATE
##FORMAT
##NULL
##WRONG

# %%
#duplicate
penguins[penguins.duplicated()]
#no duplicate
#also format is correct
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex]
# Index: []

# %%
#checking unique valu
col=penguins.columns
col
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
for i in col:
    r=penguins[i].value_counts()
    print(r)
#no worng val
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64
# 41.1    7
# 45.2    6
# 39.6    5
# 50.5    5
# 50.0    5
#        ..
# 35.6    1
# 36.8    1
# 43.1    1
# 38.5    1
# 49.9    1
# Name: bill_length_mm, Length: 164, dtype: int64
# 17.0    12
# 18.6    10
# 17.9    10
# 15.0    10
# 18.5    10
#         ..
# 13.2     1
# 14.9     1
# 21.5     1
# 20.2     1
# 17.4     1
# Name: bill_depth_mm, Length: 80, dtype: int64
# 190.0    22
# 195.0    17
# 187.0    16
# 193.0    15
# 210.0    14
# 191.0    13
# 215.0    12
# 197.0    10
# 196.0    10
# 185.0     9
# 220.0     8
# 198.0     8
# 208.0     8
# 216.0     8
# 212.0     7
# 186.0     7
# 181.0     7
# 189.0     7
# 230.0     7
# 192.0     7
# 184.0     7
# 199.0     6
# 213.0     6
# 188.0     6
# 214.0     6
# 217.0     6
# 222.0     6
# 201.0     6
# 219.0     5
# 209.0     5
# 218.0     5
# 221.0     5
# ...

# %%
#null
penguins.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
#since null values are less we can drop them
penguins1=penguins.dropna()

# %%
penguins1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
#analysis
penguins1.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
#analysis
penguins1['species'].value_counts()
# Out:
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: species, dtype: int64

# %%
penguins1['island'].value_counts()
# Out:
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: island, dtype: int64

# %%
penguins1.groupby(['island','species']).mean()
# Out:
#                      bill_length_mm  bill_depth_mm  flipper_length_mm  \
# island    species
# Biscoe    Adelie          38.975000      18.370455         188.795455
#           Gentoo          47.568067      14.996639         217.235294
# Dream     Adelie          38.520000      18.240000         189.927273
#           Chinstrap       48.833824      18.420588         195.823529
# Torgersen Adelie          39.038298      18.451064         191.531915
#
#                      body_mass_g
# island    species
# Biscoe    Adelie     3709.659091
#           Gentoo     5092.436975
# Dream     Adelie     3701.363636
#           Chinstrap  3733.088235
# Torgersen Adelie     3708.510638

# %%
penguins1.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
#vis

# %%
fig=plt.subplots(2,2,figsize=(10,10))
plt.subplot(221)
sns.scatterplot(x=penguins1['body_mass_g'],y=penguins1['flipper_length_mm'],hue=penguins1['species'])
plt.title('mass vs flipper')


plt.subplot(222)
sns.scatterplot(x=penguins1['body_mass_g'],y=penguins1['bill_depth_mm'],hue=penguins1['species'])
plt.title('mass vs bill_depth_mm')

plt.subplot(223)
sns.scatterplot(x=penguins1['body_mass_g'],y=penguins1['bill_length_mm'],hue=penguins1['species'])
plt.title('mass vs bill_length_mm')

plt.subplot(224)
sns.scatterplot(x=penguins1['bill_depth_mm'],y=penguins1['bill_length_mm'],hue=penguins1['species'])
plt.title('bill_depth_mm vs bill_length_mm')
# Out:
# Text(0.5, 1.0, 'bill_depth_mm vs bill_length_mm')

# %%
fig=plt.subplots(2,2,figsize=(10,10))
plt.subplot(221)
sns.scatterplot(x=penguins1['body_mass_g'],y=penguins1['flipper_length_mm'],hue=penguins1['sex'])
plt.title('mass vs flipper')


plt.subplot(222)
sns.scatterplot(x=penguins1['body_mass_g'],y=penguins1['bill_depth_mm'],hue=penguins1['sex'])
plt.title('mass vs bill_depth_mm')

plt.subplot(223)
sns.scatterplot(x=penguins1['body_mass_g'],y=penguins1['bill_length_mm'],hue=penguins1['sex'])
plt.title('mass vs bill_length_mm')

plt.subplot(224)
sns.scatterplot(x=penguins1['bill_depth_mm'],y=penguins1['bill_length_mm'],hue=penguins1['sex'])
plt.title('bill_depth_mm vs bill_length_mm')
# Out:
# Text(0.5, 1.0, 'bill_depth_mm vs bill_length_mm')

# %%
sns.pairplot(data=penguins1,hue='species')

# %%
penguins1.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
#
#                    body_mass_g
# bill_length_mm        0.589451
# bill_depth_mm        -0.472016
# flipper_length_mm     0.872979
# body_mass_g           1.000000

# %%
sns.heatmap(penguins1.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(penguins1.corr(),annot=True,cmap='twilight_shifted_s')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 sns.heatmap(penguins1.corr(),annot=True,cmap='twilight_shifted_s')
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:540, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
# ...
